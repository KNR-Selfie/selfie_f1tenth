# %%
lin=open('linear', 'rb')
ang=open('angular', 'rb')

# %%
import numpy as np
linear_acc = np.load(lin)
angular_vec = np.load(ang)

# %%
np.std(linear_acc, axis=0)
# Out:
# array([0.13331151, 0.03770506, 0.0648587 ])

# %%
np.mean(angular_vec, axis=0)
# Out:
# array([ -0.59854539,   0.09892786, -11.40211944])

# %%
import matplotlib.pyplot as plt
plt.plot(linear_acc)
plt.ylabel('linear acceleration')
plt.show()

# %%
plt.plot(linear_acc[:,1], 'r.')
plt.ylabel('angular velocity')
plt.show()
np.mean(angular_vec, axis=0)
# Out:
# array([ -0.59854539,   0.09892786, -11.40211944])

# %%
a = 9.891289
print('acceleration = ' + repr(a**2) + 
     ' marcel')
# Out:
# acceleration = 97.83759808152101 marcel
